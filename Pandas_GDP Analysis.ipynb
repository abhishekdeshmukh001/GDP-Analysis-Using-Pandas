# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\7.30 PM DATA SCIENCE AND AI\DAILY SESSION MATERIALS\SEPT\1st\data.csv')
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
# Top 5 rows

df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Bottom 5 rows

df.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# No. of rows and columns

df.shape
# Out:
# (195, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
# Column names

df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df[15:35]
# Out:
#                  CountryName CountryCode  BirthRate  InternetUsers  \
# 15                Bangladesh         BGD     20.142        6.63000
# 16                  Bulgaria         BGR      9.200       53.06150
# 17                   Bahrain         BHR     15.040       90.00004
# 18              Bahamas, The         BHS     15.339       72.00000
# 19    Bosnia and Herzegovina         BIH      9.062       57.79000
# 20                   Belarus         BLR     12.500       54.17000
# 21                    Belize         BLZ     23.092       33.60000
# 22                   Bermuda         BMU     10.400       95.30000
# 23                   Bolivia         BOL     24.236       36.94000
# 24                    Brazil         BRA     14.931       51.04000
# 25                  Barbados         BRB     12.188       73.00000
# 26         Brunei Darussalam         BRN     16.405       64.50000
# 27                    Bhutan         BTN     18.134       29.90000
# ...

# %%
# Entire Dataframe

df[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
# Get every 30th row

df[::30]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244          78.90          High income
# 30       Canada         CAN     10.900          85.80          High income
# 60        Gabon         GAB     30.555           9.20  Upper middle income
# 90   Kazakhstan         KAZ     22.730          54.00  Upper middle income
# 120  Mozambique         MOZ     39.705           5.40           Low income
# 150       Sudan         SDN     33.477          22.70  Lower middle income
# 180     Uruguay         URY     14.374          57.69          High income

# %%
df['CountryName'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
df[['CountryName','InternetUsers']].head()
# Out:
#             CountryName  InternetUsers
# 0                 Aruba           78.9
# 1           Afghanistan            5.9
# 2                Angola           19.1
# 3               Albania           57.2
# 4  United Arab Emirates           88.0

# %%
df[['CountryName', 'InternetUsers']].tail()
# Out:
#           CountryName  InternetUsers
# 190       Yemen, Rep.           20.0
# 191      South Africa           46.5
# 192  Congo, Dem. Rep.            2.2
# 193            Zambia           15.4
# 194          Zimbabwe           18.5

# %%
df[['CountryName', 'BirthRate']][:10]
# Out:
#             CountryName  BirthRate
# 0                 Aruba     10.244
# 1           Afghanistan     35.253
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447
# 8             Australia     13.200
# 9               Austria      9.400

# %%
# New Calculation

df['New_Calc'] = df.BirthRate * df.InternetUsers

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  New_Calc
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 3    Upper middle income  736.5644
# ...

# %%
# Drop New_Calc Column

df.drop('New_Calc', axis=1)
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
# Create new Filter --> Internet Users < 10

Filter1 = df.InternetUsers < 10

# %%
Filter1
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[Filter1]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 15                 Bangladesh         BGD     20.142           6.63
# 29   Central African Republic         CAF     34.076           3.50
# 34              Cote d'Ivoire         CIV     37.320           8.40
# 35                   Cameroon         CMR     37.236           6.40
# 36                Congo, Rep.         COG     37.011           6.60
# 38                    Comoros         COM     34.326           6.50
# 46                   Djibouti         DJI     25.486           9.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# ...

# %%
df[Filter1].head()
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 1    Afghanistan         AFG     35.253           5.90           Low income
# 11       Burundi         BDI     44.151           1.30           Low income
# 13         Benin         BEN     36.440           4.90           Low income
# 14  Burkina Faso         BFA     40.551           9.10           Low income
# 15    Bangladesh         BGD     20.142           6.63  Lower middle income
#
#      New_Calc
# 1   207.99270
# 11   57.39630
# 13  178.55600
# 14  369.01410
# 15  133.54146

# %%
# Create new Filter --> Birth Rate > 25

Filter2 = df.BirthRate > 25

# %%
Filter2
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 190     True
# 191    False
# 192     True
# 193     True
# 194     True
# Name: BirthRate, Length: 195, dtype: bool

# %%
df[Filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 1         Afghanistan         AFG     35.253            5.9
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 13              Benin         BEN     36.440            4.9
# 14       Burkina Faso         BFA     40.551            9.1
# ..                ...         ...        ...            ...
# 189             Samoa         WSM     26.172           15.3
# 190       Yemen, Rep.         YEM     32.947           20.0
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  New_Calc
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 11            Low income   57.3963
# 13            Low income  178.5560
# 14            Low income  369.0141
# ...

# %%
df[Filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 1         Afghanistan         AFG     35.253            5.9
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 13              Benin         BEN     36.440            4.9
# 14       Burkina Faso         BFA     40.551            9.1
# ..                ...         ...        ...            ...
# 189             Samoa         WSM     26.172           15.3
# 190       Yemen, Rep.         YEM     32.947           20.0
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  New_Calc
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 11            Low income   57.3963
# 13            Low income  178.5560
# 14            Low income  369.0141
# ...

# %%
Res_Filter = Filter1 & Filter2

# %%
Res_Filter
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Length: 195, dtype: bool

# %%
df[Res_Filter]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 34              Cote d'Ivoire         CIV     37.320           8.40
# 35                   Cameroon         CMR     37.236           6.40
# 36                Congo, Rep.         COG     37.011           6.60
# 38                    Comoros         COM     34.326           6.50
# 46                   Djibouti         DJI     25.486           9.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# 60                      Gabon         GAB     30.555           9.20
# ...

# %%
df[Res_Filter][:10]
# Out:
#                  CountryName CountryCode  BirthRate  InternetUsers  \
# 1                Afghanistan         AFG     35.253            5.9
# 11                   Burundi         BDI     44.151            1.3
# 13                     Benin         BEN     36.440            4.9
# 14              Burkina Faso         BFA     40.551            9.1
# 29  Central African Republic         CAF     34.076            3.5
# 34             Cote d'Ivoire         CIV     37.320            8.4
# 35                  Cameroon         CMR     37.236            6.4
# 36               Congo, Rep.         COG     37.011            6.6
# 38                   Comoros         COM     34.326            6.5
# 46                  Djibouti         DJI     25.486            9.5
#
#             IncomeGroup  New_Calc
# 1            Low income  207.9927
# 11           Low income   57.3963
# 13           Low income  178.5560
# 14           Low income  369.0141
# 29           Low income  119.2660
# ...

# %%
df[df.IncomeGroup == 'High income']
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup  \
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
#        New_Calc
# ...

# %%
# Unique Income Groups

df.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  New_Calc
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 3    Upper middle income  736.5644
# ...

# %% [markdown]
# ### Creating Visualizations using Matplotlib and Seaborn

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  New_Calc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
df.drop('New_Calc', axis=1, inplace=True)
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# 1. Distplot

v1 = sns.distplot(df["InternetUsers"])

# %%
# 2. Box Plots

v2 = sns.boxplot(data = df, x='IncomeGroup', y='BirthRate')

# %%
# LM Plot --> (Linear Model) Plot

v3 = sns.lmplot(data = df, x='InternetUsers', y='BirthRate')

# %%
v4 = sns.lmplot(data = df, x='InternetUsers', y='BirthRate', hue='IncomeGroup')
